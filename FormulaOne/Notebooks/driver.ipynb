# %%
import numpy as np
import pandas as pd

# %%
driver=pd.read_csv('F1_Driver_Standings.csv',sep=',')
driver
# Out:
#      Pos                  Driver Nationality                        Car   PTS  \
# 0      1         Nino Farina FAR         ITA                 Alfa Romeo  30.0
# 1      2  Juan Manuel Fangio FAN         ARG                 Alfa Romeo  27.0
# 2      3       Luigi Fagioli FAG         ITA                 Alfa Romeo  24.0
# 3      4       Louis  Rosier ROS         FRA                Talbot-Lago  13.0
# 4      5      Alberto Ascari ASC         ITA                    Ferrari  11.0
# ...   ..                     ...         ...                        ...   ...
# 1591  17     Nicholas Latifi LAT         CAN          Williams Mercedes   7.0
# 1592  18  Antonio Giovinazzi GIO         ITA  Alfa Romeo Racing Ferrari   3.0
# 1593  19     Mick Schumacher MSC         GER               Haas Ferrari   0.0
# 1594  20       Robert Kubica KUB         POL  Alfa Romeo Racing Ferrari   0.0
# 1595  21      Nikita Mazepin MAZ         RAF               Haas Ferrari   0.0
#
#                        Year
# ...

# %%
driver['Year'].dtype
# Out:
# dtype('O')
